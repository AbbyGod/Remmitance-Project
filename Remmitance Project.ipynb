# %%
import pandas as pd

# %%
df = pd.DataFrame({
                   'Provider': ['Moncash', 'WesternUnion', 'CAM', 'Remitly', 'WorldRemit'],
                   'Fee': [2.99, 4.99, 3.50, 5.50, 6.00],
                   'Amount': [12887, 12519, 12801, 12440, 12300]
                   })
df.to_csv("remmittance_data.csv", index=False)
print(df)
# Out:
#        Provider   Fee  Amount
# 0       Moncash  2.99   12887
# 1  WesternUnion  4.99   12519
# 2           CAM  3.50   12801
# 3       Remitly  5.50   12440
# 4    WorldRemit  6.00   12300

# %%
print("Fees under $5")

print(df[df["Fee"] < 5])
# Out:
# Fees under $5
#        Provider   Fee  Amount
# 0       Moncash  2.99   12887
# 1  WesternUnion  4.99   12519
# 2           CAM  3.50   12801

# %%
df.sort_values(by="Amount", ascending=False)
# Out:
#        Provider   Fee  Amount
# 0       Moncash  2.99   12887
# 2           CAM  3.50   12801
# 1  WesternUnion  4.99   12519
# 3       Remitly  5.50   12440
# 4    WorldRemit  6.00   12300

# %%
best = df.loc[df["Amount"].idxmax()]
print(f"The best provider is {best['Provider']} giving {best['Amount']}")
# Out:
# The best provider is Moncash giving 12887

# %%
#Next time dont forget to add the other features
